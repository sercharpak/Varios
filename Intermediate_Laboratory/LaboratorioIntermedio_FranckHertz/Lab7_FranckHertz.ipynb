# %%
# %pylab inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi
import glob
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['power', 'random', 'fft', 'load', 'save', 'linalg', 'info']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
def local_minima(xval, yval):
    xval = np.asarray(xval)
    yval = np.asarray(yval)
    sort_idx = np.argsort(xval)
    yval = yval[sort_idx]
    gradient = np.diff(yval)
    maxima = np.diff((gradient < 0).view(np.int8))
    return np.concatenate((([0],) if gradient[0] > 0 else ()) +
                          (np.where(maxima == -1)[0] + 1,) +
                          (([len(yval)-1],) if gradient[-1] > 0 else ()))
def local_maxima(xval, yval):
    xval = np.asarray(xval)
    yval = np.asarray(yval)
    sort_idx = np.argsort(xval)
    yval = yval[sort_idx]
    gradient = np.diff(yval)
    maxima = np.diff((gradient > 0).view(np.int8))
    return np.concatenate((([0],) if gradient[0] < 0 else ()) +
                          (np.where(maxima == -1)[0] + 1,) +
                          (([len(yval)-1],) if gradient[-1] > 0 else ()))

# %%
fileset = glob.glob('*.dat')
for nfile in fileset:
    arregloStrings = nfile.split('_')
    temperatura=arregloStrings[1]
    data = np.loadtxt(nfile)
    columna0=data[:,0]
    columna1=data[:,1]
    #Ya tenemos las dos columnas
    plt.title('Corriente IA (nA) vs Voltaje U1 (V) a '+temperatura+' grados Centigrados')
    plt.xlabel('Voltaje U1 (V)')
    plt.ylabel('Corriente IA (nA)')
    plt.xlim(0.0,max(columna0)+1)
    plt.ylim(0,max(columna1)+1)
    plt.plot(columna0, columna1,marker="o", markerfacecolor="b")
    plt.show()
    b=local_minima(columna0,columna1)
    print b
    c=local_maxima(columna0,columna1)
# Out:
# [   2    5    8   11   13   16   19   22   27   32   38   41   43   46   48
#    57   60   62   71   73   76   87   90   92   95   98  101  103  106  109
#   114  117  123  125  131  133  136  147  152  158  161  163  166  169  173
#   177  182  188  194  196  198  204  207  209  215  218  221  223  226  229
#   237  253  256  267  278  281  283  286  288  297  313  316  318  327  330
#   332  340  343  346  348  357  359  365  373  376  379  384  387  389  401
#   408  411  417  420  428  430  438  518  523  526  528  532  534  537  540
#   545  556  570  575  578  586  592  594  597  600  608  714  796  799  801
#   804  913 1000 1005 1118 1207 1412 1533 1836 1940 2098 2163 2269]
# [   0    5    9   17   19   21   24   27   33   38   44   47   49   52   54
#    58   64   66   68   77   79   82   85   90   94  104  107  109  112  114
#   123  131  137  139  142  145  150  153  155  161  164  169  172  175  177
#   183  186  191  194  199  202  213  216  218  224  229  232  234  240  243
#   245  249  251  254  257  259  262  264  270  273  275  281  284  287  289
#   292  294  303  305  314  319  322  324  327  330  333  335  344  346  350
#   352  354  363  365  371  374  376  379  382  384  387  393  396  398  401
#   404  406  409  412  415  417  420  423  425  434  436  439  444  450  455
